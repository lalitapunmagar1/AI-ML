# %% [markdown]
# <a href="https://colab.research.google.com/github/lalitapunmagar1/AI-ML/blob/main/Pandas/pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ###Pandas

# %%
import pandas as pd
data = {
    "cars": ["bmw", "honda", "deepal", "byd"],
    "models": ["2007", "2008", "2024", "2015"],
    "passen": ["4", "5", "4", "6"]
}
data
# Out:
# {'cars': ['bmw', 'honda', 'deepal', 'byd'],
#  'models': ['2007', '2008', '2024', '2015'],
#  'passen': ['4', '5', '4', '6']}

# %%
#convert the data dictionary to data frame
df= pd.DataFrame(data)
df
# Out:
#      cars models passen
# 0     bmw   2007      4
# 1   honda   2008      5
# 2  deepal   2024      4
# 3     byd   2015      6

# %%
df.to_csv("//content/drive/MyDrive/Colab Notebooks/pandascar_data.csv")

# %%
df= pd.read_csv("/content/drive/MyDrive/Colab Notebooks/pandascar_data.csv")
df
# Out:
#    Unnamed: 0    cars  models  passen
# 0           0     bmw    2007       4
# 1           1   honda    2008       5
# 2           2  deepal    2024       4
# 3           3     byd    2015       6

# %%
import pandas as pd
data = {
    "calories": ["420", "500", "390"],
    "duration": ["50", "60", "45"]
}
data
# Out:
# {'calories': ['420', '500', '390'], 'duration': ['50', '60', '45']}

# %%
df = pd.DataFrame(data)
df
# Out:
#   calories duration
# 0      420       50
# 1      500       60
# 2      390       45

# %%
df.to_csv("//content/drive/MyDrive/Colab Notebooks/pandascalories_data.csv")

# %%
df = pd.read_csv("//content/drive/MyDrive/Colab Notebooks/pandascalories_data.csv")
df
# Out:
#    Unnamed: 0  calories  duration
# 0           0       420        50
# 1           1       500        60
# 2           2       390        45
